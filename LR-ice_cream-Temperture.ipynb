# %% [markdown]
# # Step 1: Data Generation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # Step 2: Data Preparation

# %%
data = pd.read_csv('IceCreamData.csv')
data
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
# Plot the data
plt.scatter(data['Temperature'], data['Revenue'])
plt.xlabel('Temperature of City')
plt.ylabel('Revenue of city')
plt.title('Temperature vs Revenue')
plt.show()

# %% [markdown]
# # Step 3: Data Splitting

# %%
# Split the data into training and testing sets (80% training, 20% testing)
x= data[['Temperature']]
y=data['Revenue']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Step 4: Linear Regression Modeling

# %%
# create and train a linear regression model
model=LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Step 5: Model Evaluation

# %%
# Make predictions on the testing data
y_pred = model.predict(X_test)

# %%
# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse:.2f}')
print(f'R-squared: {r2:.2f}')
# Out:
# Mean Squared Error: 652.52
# R-squared: 0.98

# %% [markdown]
# # Step 6: Visualization and Interpretation

# %%
# Plot the regression line and data points
plt.scatter(X_test, y_test, color='blue', label='Actual Data')
plt.plot(X_test, y_pred, color='red', label='Regression Line', linewidth=2)
plt.xlabel('City Temperature')
plt.ylabel('City Revenue')
plt.legend()
plt.title('Simple Linear Regression: City Temperature vs. City Revenue')
plt.show()

# %%
# Interpret the model's coefficients
slope = model.coef_[0]
intercept = model.intercept_

print(f'Slope (Coefficient): {slope:.2f}')
print(f'Intercept: {intercept:.2f}')
# Out:
# Slope (Coefficient): 21.38
# Intercept: 46.80

# %%
Temperature=int(input("Enter City Temperature :"))
Revenue=model.predict([[Temperature]])
print("City Temperature is : ",Temperature,"\n","City Revenue is : ",Revenue[0])
# Out:
# City Temperature is :  25
#  City Revenue is :  581.3539876598
# c:\Users\ravia\anaconda3\envs\Machine-learning\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
